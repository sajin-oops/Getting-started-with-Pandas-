# %%
# Subset of a DataFrame
import pandas as pd

# %%
titanic = pd.read_csv("/Users/sajin/Datasets/tested.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
ages = titanic["Age"]

# %%
ages
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages.shape
# Out:
# (418,)

# %%
titanic["Age"].shape
# Out:
# (418,)

# %%
name_age = titanic[["Name","Age"]]

# %%
name_age
# Out:
#                                              Name   Age
# 0                                Kelly, Mr. James  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0
# 2                       Myles, Mr. Thomas Francis  62.0
# 3                                Wirz, Mr. Albert  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..                                            ...   ...
# 413                            Spector, Mr. Woolf   NaN
# 414                  Oliva y Ocana, Dona. Fermina  39.0
# 415                  Saether, Mr. Simon Sivertsen  38.5
# 416                           Ware, Mr. Frederick   NaN
# 417                      Peter, Master. Michael J   NaN
#
# [418 rows x 2 columns]

# %%
type(name_age)
# Out:
# pandas.core.frame.DataFrame

# %%
above_35 = titanic[titanic["Age"] > 35]

# %%
above_35.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 1 to 415
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  105 non-null    int64
#  1   Survived     105 non-null    int64
#  2   Pclass       105 non-null    int64
#  3   Name         105 non-null    object
#  4   Sex          105 non-null    object
#  5   Age          105 non-null    float64
#  6   SibSp        105 non-null    int64
#  7   Parch        105 non-null    int64
#  8   Ticket       105 non-null    object
#  9   Fare         104 non-null    float64
#  10  Cabin        51 non-null     object
#  11  Embarked     105 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 10.7+ KB

# %%
above_40 = titanic["Age"] > 40

# %%
above_40
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Age, Length: 418, dtype: bool

# %%
type(above_40)
# Out:
# pandas.core.series.Series

# %%
above_40.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 418 entries, 0 to 417
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 418 non-null    bool
# dtypes: bool(1)
# memory usage: 550.0 bytes

# %%
titanic["Age"] > 35
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 413    False
# 414     True
# 415     True
# 416    False
# 417    False
# Name: Age, Length: 418, dtype: bool

# %%
above_40.shape
# Out:
# (418,)

# %%
above_35.shape
# Out:
# (105, 12)

# %%
type(above_35)
# Out:
# pandas.core.frame.DataFrame

# %%
unique_pclass = titanic["Pclass"]

# %%
unique_pclass
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
unique_pclass = titanic["Pclass"].unique()

# %%
unique_pclass
# Out:
# array([3, 2, 1])

# %%
class_12 = titanic[titanic['Pclass'].isin([1,2])]

# %%
class_12.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 2           894         0       2
# 7           899         0       2
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 7                    Caldwell, Mr. Albert Francis    male  26.0      1      1
# 11                     Jones, Mr. Charles Cresson    male  46.0      0      0
# 12  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1      0
# 13                           Howard, Mr. Benjamin    male  63.0      1      0
#
#     Ticket     Fare Cabin Embarked
# 2   240276   9.6875   NaN        Q
# 7   248738  29.0000   NaN        S
# 11     694  26.0000   NaN        S
# 12   21228  82.2667   B45        S
# 13   24065  26.0000   NaN        S

# %%
class_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 2 to 414
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  200 non-null    int64
#  1   Survived     200 non-null    int64
#  2   Pclass       200 non-null    int64
#  3   Name         200 non-null    object
#  4   Sex          200 non-null    object
#  5   Age          186 non-null    float64
#  6   SibSp        200 non-null    int64
#  7   Parch        200 non-null    int64
#  8   Ticket       200 non-null    object
#  9   Fare         200 non-null    float64
#  10  Cabin        87 non-null     object
#  11  Embarked     200 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 20.3+ KB

# %%
age_no_na = titanic["Age"].notna()

# %%
age_no_na
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 413    False
# 414     True
# 415     True
# 416    False
# 417    False
# Name: Age, Length: 418, dtype: bool
