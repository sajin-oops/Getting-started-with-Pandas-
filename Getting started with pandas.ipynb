# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Name": ["Sajin","Aaron","Lijin"],
    "Age":[23,22,21],
    "Gender":["Male","Male","Male"],

})

# %%
df
# Out:
#     Name  Age Gender
# 0  Sajin   23   Male
# 1  Aaron   22   Male
# 2  Lijin   21   Male

# %%
df["Age"]
# Out:
# 0    23
# 1    22
# 2    21
# Name: Age, dtype: int64

# %%
df["Name"]
# Out:
# 0    Sajin
# 1    Aaron
# 2    Lijin
# Name: Name, dtype: object

# %%
df["Gender"]
# Out:
# 0    Male
# 1    Male
# 2    Male
# Name: Gender, dtype: object

# %%
df["Age"].max()
# Out:
# 23

# %%
df["Age"].min()
# Out:
# 21

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   22.0
# std     1.0
# min    21.0
# 25%    21.5
# 50%    22.0
# 75%    22.5
# max    23.0
